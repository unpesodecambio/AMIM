# %% [markdown]
# # Inicio

# %% [markdown]
# ![p.png](attachment:8fc03d5d-52ec-4415-9dbb-f8e948741eb6.png)

# %% [markdown]
# * Lista

# %% [markdown]
# # Tipos de datos

# %%
entero = 3 # Este es un tipo de dato, en este caso enteros
flotante = 2.2
cadena = "hola"
lista = [1, 2.2, "hola"]
diccionario = {"clave1": "valor1", "clave2": 2}

print ("Lista: ", lista[1])
# Out:
# Lista:  2.2

# %%
print ("Diccionario: ", diccionario["clave1"])
# Out:
# Diccionario:  valor1

# %% [markdown]
# # Operadores numéricos

# %%
num1 = 5
num2 = 8
suma = num1 + num2
resta = num1 - num2
mul = num1 * num2
division = num1 / num2
modulo = num1 % num2
exponentes = num1 ** num2
print (exponentes)
# Out:
# 390625

# %% [markdown]
# # Operadores lógicos y relacionales

# %%
edad = 18
licencia = False
coche = False

conducir = (edad >= 18) and (licencia == True)
print ("¿Puede conducir?", conducir)
# Out:
# ¿Puede conducir? False

# %%
conducir = (edad >= 16) or (licencia == True)
print ("¿Puede conducir?", conducir)
# Out:
# ¿Puede conducir? True

# %% [markdown]
# # Estructura de control: If

# %%
num1 = 3
num2 = 5
resultado = num1 + num2
if num1 > num2 :
    print (resultado)
else :
    print ("no se cumplio")
# Out:
# no se cumplio

# %%
num1 = 3
num2 = 5
resultado = num1 + num2
if num1 > num2 :
    print (resultado)
elif num1 < num2 :
    print ("elif")
# Out:
# elif

# %% [markdown]
# # Manipulación de datos

# %%
import pandas as pd
import numpy as np

# %%
data = {
'Nomre' : ['Çarlos', 'María', 'Juan'],
'Edad' : [25, 30, 35],
'Ciudad' : ['Madrid', 'Barcelona', 'Sevilla']
}

df = pd.DataFrame(data)

# %%
df['Edad'].median()
# Out:
# 30.0
