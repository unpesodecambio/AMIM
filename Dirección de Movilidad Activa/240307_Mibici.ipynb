# %%
# !pip install geopandas
# Out:
# ...
#   Obtaining dependency information for geopandas from https://files.pythonhosted.org/packages/90/37/08e416c9915dcf7d53deb0fbdb702266902c584617dfa6e6c84fb2fc6ee3/geopandas-0.14.3-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fiona>=1.8.21 from https://files.pythonhosted.org/packages/7f/27/b24c1610c7ae5716709321f04d38d7b8b71ed531f80df4f697b9ad99cfc3/fiona-1.9.5-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/51.1 kB ? eta -:--:--
#      --------------- ---------------------- 20.5/51.1 kB 682.7 kB/s eta 0:00:01
#      -------------------------------------- 51.1/51.1 kB 659.2 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
import geopandas as gpd

# %%
MZNA_JAL_ruta = r"C:\Users\UTIC\Downloads\DENI_JAL.gpkg"


MZNA_JAL_gdpkg = gpd.read_file(MZNA_JAL_ruta)

# %%
municipios = ['002', '051']

# %%
MZNA_JAL_ruta_sal = r"C:\Users\UTIC\Downloads\DENI_JAL_FIL.gpkg"

MZNA_JAL_gdpkg_filter = MZNA_JAL_gdpkg[MZNA_JAL_gdpkg['CVE_MUN'].isin(municipios)]

MZNA_JAL_gdpkg_filter.to_file(MZNA_JAL_ruta_sal, layer='FILTRO', driver='GPKG')

# %%
MZNA_JAL_gdpkg_filter
# Out:
#                   CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB CVE_MZA  AMBITO  \
# 1568    1100200010535030      11     002    0001     0535     030  Urbana
# 1569    1100200010501022      11     002    0001     0501     022  Urbana
# 1570    1100200010535036      11     002    0001     0535     036  Urbana
# 1571    1100200010535032      11     002    0001     0535     032  Urbana
# 1572    1100200011321001      11     002    0001     1321     001  Urbana
# ...                  ...     ...     ...     ...      ...     ...     ...
# 112893         110020022      11     002    0022        0       0   Rural
# 112894         110020092      11     002    0092        0       0   Rural
# 112895         110020123      11     002    0123        0       0   Rural
# 112896         110020023      11     002    0023        0       0   Rural
# 112897         110020481      11     002    0481        0       0   Rural
#
#        TIPOMZA                          NOMGEO  POBTOT_MZNA_2020  ...  \
# ...
